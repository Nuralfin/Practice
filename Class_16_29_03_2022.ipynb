# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel(r'C:/Users/pyari/Desktop/crop.xlsx')

# %%
df
# Out:
#     Year    rice   wheat   Maize  pulses
# 0   1980     235   81264    2354    6432
# 1   1981    6324    1274    8234   87632
# 2   1982    7821  192873   97283    8723
# 3   1983    9328     127     293     732
# 4   1984     983   91273    9273    8732
# 5   1985   12891  721948    1820     406
# 6   1986       9   19248    8743    9823
# 7   1987     192    1749   89273    9732
# 8   1988     832    2387     237     623
# 9   1989     123   92183    9832     823
# 10  1990     913    9234     311      93
# 11  1991    9123      84     327      48
# 12  1992     912   98347      32    8613
# 13  1993     192     943     932     975
# 14  1994    1909     329      32      74
# 15  1995   19236     923    8326     416
# 16  1996     194     273   98263     408
# 17  1997  129816     218  986328       4
# 18  1998     192    3230      94     484
# 19  1999     913    2384      38      94
# 20  2000     231     327     973     974

# %%
plt.plot(df["rice"])

# %%
plt.plot(df["Year"],df["rice"])

# %%
fig = plt.figure(figsize=(4,5))
ax = fig.add_subplot(111)
ax.plot(df["Year"],df["rice"])
ax.set_xlim([1980,2000])
ax.set_ylim([0,140000])
ax.set_xlabel("Time")
ax.set_ylabel("Production")
ax.set_title("Food Production")

plt.show()

# %%
fig, axes = plt.subplots(nrows=2,ncols=2,figsize=(8,8))
axes[1,1].set(title="rajgir",xlim=[0,10],ylim=[0,20])
axes[0,0].set(title="Ghoda katora",xlim=[0,15],ylim=[0,22])
# Out:
# [(0.0, 22.0), (0.0, 15.0), Text(0.5, 1.0, 'Ghoda katora')]

# %%
fig = plt.figure(figsize=(8,8))
ax1 = plt.subplot(221)
ax2 = plt.subplot(222)
ax3 = plt.subplot(223)
ax4 = plt.subplot(224)


ax3.set(title="Ghoda katora",xlim=[0,15],ylim=[0,22])
# Out:
# [(0.0, 22.0), (0.0, 15.0), Text(0.5, 1.0, 'Ghoda katora')]

# %%
fig = plt.figure(figsize=(8,5))
ax1 = plt.subplot(111)
ax1.plot(df["Year"],df["rice"],color='coral', marker='s', linestyle=':', linewidth=2, markersize=8)
ax1.plot(df["Year"],df["wheat"],color='green', marker='s', linestyle='-', linewidth=2, markersize=8)

# %%
fig = plt.figure(figsize=(8,5))
ax1 = plt.subplot(221)
ax2 = plt.subplot(222)
ax3 = plt.subplot(223)
ax4 = plt.subplot(224)
ax1.plot(df["Year"],df["rice"],color='coral', marker='s', linestyle=':', linewidth=2, markersize=8)
ax2.plot(df["Year"],df["wheat"],color='green', marker='s', linestyle='-', linewidth=2, markersize=8)
ax3.plot(df["Year"],df["Maize"],color='coral', marker='s', linestyle=':', linewidth=2, markersize=8)
ax4.plot(df["Year"],df["pulses"],color='green', marker='s', linestyle='-', linewidth=2, markersize=8)

# %%
fig = plt.figure(figsize=(10,5))
ax1 = plt.subplot(111)
ax1.plot(df["Year"],df["rice"],color='coral', marker='s', linestyle=':', linewidth=2, markersize=8)
ax1.set(xlim=[1980,2000],ylim=[0,140000])
ax1.set_xlabel("year",fontsize=20)
ax1.set_ylabel("production",fontsize=20)
plt.savefig('output.eps', format='eps',orientation='landscape', dpi=300)

# %%
a
# Out:
# array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000])

# %%
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-101-a62d01c1d62e> in <module>
# ----> 1 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'
