# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel(r'C:/Users/pyari/Desktop/crop.xlsx')

# %%
fig, ax = plt.subplots()
mycolors = ["cyan", "violet","blue", "orange"]
mylabels = ["orange", "mango", "banana","kiwi"]
myexplode = [0, 0, 0.6, 0]
#plt.pie(x, colors=mycolors, radius=3, center=(4, 4),labels = mylabels,explode = myexplode,
#       wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True))
ax.pie(x, colors=mycolors, radius=3, center=(4, 4), labels = mylabels,explode = myexplode)
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))

# %%
fig, ax = plt.subplots()
mycolors = ["cyan", "violet","blue", "orange"]
mylabels = ["orange", "mango", "banana","kiwi"]
myexplode = [0, 0, 0.6, 0]
#plt.pie(x, colors=mycolors, radius=3, center=(4, 4),labels = mylabels,explode = myexplode,
#       wedgeprops={"linewidth": 1, "edgecolor": "white"}, frame=True))
ax.pie(x, colors=mycolors, radius=3, center=(4, 4), labels = mylabels,explode = myexplode)
ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
       ylim=(0, 8), yticks=np.arange(1, 8))
# Out:
# [[<matplotlib.axis.YTick at 0x1af8f006130>,
# ...
#  (0.0, 8.0),
# ...
#  (0.0, 8.0)]

# %% [markdown]
# # plot with error band

# %%
x = np.random.randint (10, 30, 20)
y= np.arange(1980,2000)

# %%
x
# Out:
# array([21, 12, 25, 29, 28, 19, 10, 15, 23, 18, 25, 14, 18, 16, 22, 15, 11,
#        15, 24, 11])

# %%
y
# Out:
# array([1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990,
#        1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999])

# %%
y_error = 5

plt.plot(y, x)
plt.errorbar(y, x, yerr = y_error, fmt ='o',color = 'orange', 
            ecolor = 'lightgreen', elinewidth = 5, capsize=10)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
plt.bar(y, x)
plt.errorbar(y, x, yerr = y_error,fmt ='o',color = 'orange', 
            ecolor = 'pink', elinewidth = 5, capsize=1)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
mean_1 = np.array([10, 20, 30, 25, 32, 43])
std_1 = np.array([2.2, 2.3, 1.2, 2.2, 1.8, 3.5])
mean_2 = np.array([12, 22, 30, 13, 33, 39])
std_2 = np.array([2.4, 1.3, 2.2, 1.2, 1.9, 3.5])

x = np.arange(len(mean_1))
plt.plot(x, mean_1, 'b-', label='mean_1')
plt.fill_between(x, mean_1 - std_1, mean_1 + std_1, color='b', alpha=0.2)

plt.plot(x, mean_2, 'r-', label='mean_1')
plt.fill_between(x, mean_2 - std_2, mean_2 + std_2, color='r', alpha=0.2)
